# %%
from scrapy.crawler import CrawlerProcess
from scrapy.settings import Settings

from jobparser.spiders.hhru import HhruSpider
from jobparser.spiders.superjoberu import SuperjobRuSpider
from jobparser import settings

# %%
crawler_settings = Settings()
crawler_settings.setmodule(settings)
process = CrawlerProcess(settings=crawler_settings)

process.crawl(HhruSpider,vacancy = 'Python')
process.crawl(SuperjobRuSpider,vacancy = 'Python')
process.start()
# Out:
# 2021-03-29 21:14:44 [scrapy.utils.log] INFO: Scrapy 2.4.1 started (bot: jobparser)
# 2021-03-29 21:14:44 [scrapy.utils.log] INFO: Versions: lxml 4.2.5.0, libxml2 2.9.8, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 21.2.0, Python 3.7.1 (default, Dec 10 2018, 22:54:23) [MSC v.1915 64 bit (AMD64)], pyOpenSSL 18.0.0 (OpenSSL 1.1.1c  28 May 2019), cryptography 2.4.2, Platform Windows-10-10.0.19041-SP0
# 2021-03-29 21:14:44 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2021-03-29 21:14:44 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'jobparser',
#  'CONCURRENT_REQUESTS': 32,
#  'NEWSPIDER_MODULE': 'jobparser.spiders',
#  'SPIDER_MODULES': ['jobparser.spiders'],
#  'USER_AGENT': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, '
#                'like Gecko) Chrome/88.0.4324.96 Safari/537.36'}
# 2021-03-29 21:14:45 [scrapy.extensions.telnet] INFO: Telnet Password: fc059b5a7a585f09
# 2021-03-29 21:14:45 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2021-03-29 21:14:45 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2021-03-29 21:14:45 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2021-03-29 21:14:45 [scrapy.middleware] INFO: Enabled item pipelines:
# ['jobparser.pipelines.JobparserPipeline']
# 2021-03-29 21:14:45 [scrapy.core.engine] INFO: Spider opened
# 2021-03-29 21:14:45 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2021-03-29 21:14:45 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2021-03-29 21:14:45 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'jobparser',
#  'CONCURRENT_REQUESTS': 32,
#  'NEWSPIDER_MODULE': 'jobparser.spiders',
#  'SPIDER_MODULES': ['jobparser.spiders'],
#  'USER_AGENT': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, '
#                'like Gecko) Chrome/88.0.4324.96 Safari/537.36'}
# 2021-03-29 21:14:45 [scrapy.extensions.telnet] INFO: Telnet Password: df4c5e3c95cda9ed
# 2021-03-29 21:14:45 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2021-03-29 21:14:45 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2021-03-29 21:14:45 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2021-03-29 21:14:45 [scrapy.middleware] INFO: Enabled item pipelines:
# ['jobparser.pipelines.JobparserPipeline']
# 2021-03-29 21:14:45 [scrapy.core.engine] INFO: Spider opened
# 2021-03-29 21:14:45 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2021-03-29 21:14:45 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6024
# 2021-03-29 21:14:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python> (referer: None)
# 2021-03-29 21:14:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/43371453?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/43371453?query=Python>
# {'_id': 'f53945b24fd589f901e0be1bd19fde3cdea02c9d',
#  'link': 'https://kaliningrad.hh.ru/vacancy/43371453?query=Python',
#  'name': 'Веб-разработчик (Python Django)',
#  'salary': [],
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh'}
# 2021-03-29 21:14:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/42226188?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/30005963?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/43357165?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/43282114?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/43351933?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://russia.superjob.ru/vacancy/search/?keywords=Python> (referer: None)
# 2021-03-29 21:14:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/42226188?query=Python>
# {'_id': '1d0bc311cd5896675368150a735920550d130502',
#  'link': 'https://kaliningrad.hh.ru/vacancy/42226188?query=Python',
#  'name': 'Программист Python',
#  'salary': ['от ',
#             '140\xa0000',
#             ' до ',
#             '180\xa0000',
#             ' ',
#             'руб.',
#             ' до вычета налогов'],
#  'salary_currency': 'руб.',
#  'salary_max': 180000,
#  'salary_min': 140000,
#  'site': 'hh'}
# 2021-03-29 21:14:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/42855358?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/30005963?query=Python>
# {'_id': '3e1768d19e2e07e0329e1004dad1a02ba4904b4d',
#  'link': 'https://kaliningrad.hh.ru/vacancy/30005963?query=Python',
#  'name': 'Python developer',
#  'salary': ['от ', '4\xa0000', ' ', 'USD', ' на руки'],
#  'salary_currency': 'USD',
#  'salary_max': None,
#  'salary_min': 4000,
#  'site': 'hh'}
# 2021-03-29 21:14:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/43357165?query=Python>
# {'_id': '2c30a1748d12812cc963a6901bbb233090edcd6f',
#  'link': 'https://kaliningrad.hh.ru/vacancy/43357165?query=Python',
#  'name': 'Data Scientist / Data Engineer',
#  'salary': ['от ', '150\xa0000', ' ', 'руб.', ' на руки'],
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': 150000,
#  'site': 'hh'}
# 2021-03-29 21:14:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/43282114?query=Python>
# {'_id': '55a2a9581fbeea963b81070f998d53f9f46db8e5',
#  'link': 'https://kaliningrad.hh.ru/vacancy/43282114?query=Python',
#  'name': 'Разработчик Python',
#  'salary': ['от ', '180\xa0000', ' ', 'руб.', ' на руки'],
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': 180000,
#  'site': 'hh'}
# 2021-03-29 21:14:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/42813933?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/43351933?query=Python>
# {'_id': 'd44deb38a5e6ac3cba7b5a75e73f3c7d46168466',
#  'link': 'https://kaliningrad.hh.ru/vacancy/43351933?query=Python',
#  'name': 'Python/Django Full Stack Developer (Middle-Senior)',
#  'salary': ['от ',
#             '270\xa0000',
#             ' до ',
#             '340\xa0000',
#             ' ',
#             'руб.',
#             ' до вычета налогов'],
#  'salary_currency': 'руб.',
#  'salary_max': 340000,
#  'salary_min': 270000,
#  'site': 'hh'}
# 2021-03-29 21:14:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/42855358?query=Python>
# {'_id': 'd4ba0900e0510264d97de1a719cf4548ef49d6cd',
#  'link': 'https://kaliningrad.hh.ru/vacancy/42855358?query=Python',
#  'name': 'Python разработчик',
#  'salary': ['от ',
#             '90\xa0000',
#             ' до ',
#             '130\xa0000',
#             ' ',
#             'руб.',
#             ' до вычета налогов'],
#  'salary_currency': 'руб.',
#  'salary_max': 130000,
#  'salary_min': 90000,
#  'site': 'hh'}
# 2021-03-29 21:14:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/42813933?query=Python>
# {'_id': '1af2e4756a8bb87f7714c08272ebcb74b6cd60b4',
#  'link': 'https://kaliningrad.hh.ru/vacancy/42813933?query=Python',
#  'name': 'Data Scientist (компьютерное зрение)',
#  'salary': ['от ',
#             '70\xa0000',
#             ' до ',
#             '400\xa0000',
#             ' ',
#             'руб.',
#             ' до вычета налогов'],
#  'salary_currency': 'руб.',
#  'salary_max': 400000,
#  'salary_min': 70000,
#  'site': 'hh'}
# 2021-03-29 21:14:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/43186332?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/43289283?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/43210058?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/43242292?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/43186332?query=Python>
# {'_id': '0c1f215657d89382382e002fad564e56ccd98b49',
#  'link': 'https://kaliningrad.hh.ru/vacancy/43186332?query=Python',
#  'name': 'Senior Backend-разработчик (Python)',
#  'salary': ['от ',
#             '200\xa0000',
#             ' до ',
#             '320\xa0000',
#             ' ',
#             'руб.',
#             ' до вычета налогов'],
#  'salary_currency': 'руб.',
#  'salary_max': 320000,
#  'salary_min': 200000,
#  'site': 'hh'}
# 2021-03-29 21:14:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/43289283?query=Python>
# {'_id': '8129f29fccf224c6fd55945e8e06a94f35b9bffc',
#  'link': 'https://kaliningrad.hh.ru/vacancy/43289283?query=Python',
#  'name': 'Data Scientist / Аналитик Data Science',
#  'salary': ['от ', '130\xa0000', ' до ', '180\xa0000', ' ', 'руб.', ' на руки'],
#  'salary_currency': 'руб.',
#  'salary_max': 180000,
#  'salary_min': 130000,
#  'site': 'hh'}
# 2021-03-29 21:14:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/43210058?query=Python>
# {'_id': '6853b5560ee4448df5fb2b77f1d67a46cbc1e697',
#  'link': 'https://kaliningrad.hh.ru/vacancy/43210058?query=Python',
#  'name': 'Senior Python Developer',
#  'salary': ['от ', '6\xa0000', ' до ', '9\xa0000', ' ', 'USD', ' на руки'],
#  'salary_currency': 'USD',
#  'salary_max': 9000,
#  'salary_min': 6000,
#  'site': 'hh'}
# 2021-03-29 21:14:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/43242292?query=Python>
# {'_id': '342fe0611064663d72fe39c693143e3038ce1928',
#  'link': 'https://kaliningrad.hh.ru/vacancy/43242292?query=Python',
#  'name': 'Разработчик-Python (Django, DRF)',
#  'salary': ['от ', '170\xa0000', ' до ', '220\xa0000', ' ', 'руб.', ' на руки'],
#  'salary_currency': 'руб.',
#  'salary_max': 220000,
#  'salary_min': 170000,
#  'site': 'hh'}
# 2021-03-29 21:14:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/43228882?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/37486302?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/42277259?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/43228882?query=Python>
# {'_id': 'b959d3a7378a52b0d1078e7d07afdd577f99a501',
#  'link': 'https://kaliningrad.hh.ru/vacancy/43228882?query=Python',
#  'name': 'Программист Python',
#  'salary': ['от ', '60\xa0000', ' ', 'руб.', ' на руки'],
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': 60000,
#  'site': 'hh'}
# 2021-03-29 21:14:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/40547800?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/37486302?query=Python>
# {'_id': 'fe144a24a694a2c05d1b91c08551f6e6af679526',
#  'link': 'https://kaliningrad.hh.ru/vacancy/37486302?query=Python',
#  'name': 'Python разработчик',
#  'salary': ['от ', '150\xa0000', ' до ', '250\xa0000', ' ', 'руб.', ' на руки'],
#  'salary_currency': 'руб.',
#  'salary_max': 250000,
#  'salary_min': 150000,
#  'site': 'hh'}
# 2021-03-29 21:14:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/42766512?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/42277259?query=Python>
# {'_id': '416ee936890e78f88568a0441e340ee529786ad4',
#  'link': 'https://kaliningrad.hh.ru/vacancy/42277259?query=Python',
#  'name': 'Python-разработчик',
#  'salary': ['от ', '160\xa0000', ' до ', '200\xa0000', ' ', 'руб.', ' на руки'],
#  'salary_currency': 'руб.',
#  'salary_max': 200000,
#  'salary_min': 160000,
#  'site': 'hh'}
# 2021-03-29 21:14:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/43283683?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/40547800?query=Python>
# {'_id': '97a5752848fa9858878f83d2f28d0246f7be3660',
#  'link': 'https://kaliningrad.hh.ru/vacancy/40547800?query=Python',
#  'name': 'Python разработчик',
#  'salary': ['от ', '150\xa0000', ' до ', '220\xa0000', ' ', 'руб.', ' на руки'],
#  'salary_currency': 'руб.',
#  'salary_max': 220000,
#  'salary_min': 150000,
#  'site': 'hh'}
# 2021-03-29 21:14:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/42766512?query=Python>
# {'_id': '467948f6de743c2fbf8d73008b4fb44f3f6842a0',
#  'link': 'https://kaliningrad.hh.ru/vacancy/42766512?query=Python',
#  'name': 'Python разработчик',
#  'salary': ['от ', '1\xa0500', ' до ', '4\xa0000', ' ', 'USD', ' на руки'],
#  'salary_currency': 'USD',
#  'salary_max': 4000,
#  'salary_min': 1500,
#  'site': 'hh'}
# 2021-03-29 21:14:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/43377570?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/43283683?query=Python>
# {'_id': '380b63036acef9765b20958479f98803fe36f5d2',
#  'link': 'https://kaliningrad.hh.ru/vacancy/43283683?query=Python',
#  'name': 'Разработчик Python',
#  'salary': ['от ', '180\xa0000', ' ', 'руб.', ' на руки'],
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': 180000,
#  'site': 'hh'}
# 2021-03-29 21:14:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/43433827?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/43320192?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/43377570?query=Python>
# {'_id': '4b8051377ce7a94488857a4ac47987023a1b0724',
#  'link': 'https://kaliningrad.hh.ru/vacancy/43377570?query=Python',
#  'name': 'Junior Quantitative Researcher',
#  'salary': ['от ', '250\xa0000', ' ', 'руб.', ' на руки'],
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': 250000,
#  'site': 'hh'}
# 2021-03-29 21:14:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/39736489?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://russia.superjob.ru/vakansii/specialist-po-transportnomu-planirovaniyu-36474560.html> (referer: https://russia.superjob.ru/vacancy/search/?keywords=Python)
# 2021-03-29 21:14:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/43433827?query=Python>
# {'_id': '9d0357b69270d6e93cbb091e39e57007b588515c',
#  'link': 'https://kaliningrad.hh.ru/vacancy/43433827?query=Python',
#  'name': 'Senior Data Scientist (Computer Vision) - Syntagma Team',
#  'salary': ['з/п не указана'],
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh'}
# 2021-03-29 21:14:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/41095804?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://russia.superjob.ru/vakansii/programmist-python-36373575.html> (referer: https://russia.superjob.ru/vacancy/search/?keywords=Python)
# 2021-03-29 21:14:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/43320192?query=Python>
# {'_id': 'a6e5bb65c22ac6565d84fdc358a40bc65f058aab',
#  'link': 'https://kaliningrad.hh.ru/vacancy/43320192?query=Python',
#  'name': 'Senior Python Backend Developer (Remote)',
#  'salary': ['от ', '3\xa0000', ' ', 'USD', ' на руки'],
#  'salary_currency': 'USD',
#  'salary_max': None,
#  'salary_min': 3000,
#  'site': 'hh'}
# 2021-03-29 21:14:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/39736489?query=Python>
# {'_id': '7832507fac05fdc18e3ec54a38622602123aa502',
#  'link': 'https://kaliningrad.hh.ru/vacancy/39736489?query=Python',
#  'name': 'Python-разработчик (Django, DRF)',
#  'salary': ['от ', '60\xa0000', ' до ', '150\xa0000', ' ', 'руб.', ' на руки'],
#  'salary_currency': 'руб.',
#  'salary_max': 150000,
#  'salary_min': 60000,
#  'site': 'hh'}
# 2021-03-29 21:14:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/42802585?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://russia.superjob.ru/vakansii/specialist-po-transportnomu-planirovaniyu-36474560.html>
# {'_id': '9ad89c360ffa5ba2c2fa0a42f24179885d0f92d5',
#  'link': 'https://russia.superjob.ru/vakansii/specialist-po-transportnomu-planirovaniyu-36474560.html',
#  'name': 'Специалист по транспортному планированию, аналитик',
#  'salary': [],
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'superjobe'}
# 2021-03-29 21:14:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://russia.superjob.ru/vakansii/inzhener-po-nagruzochnomu-testirovaniyu-36496824.html> (referer: https://russia.superjob.ru/vacancy/search/?keywords=Python)
# 2021-03-29 21:14:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/41095804?query=Python>
# {'_id': 'cf41416eed23623b174cb24c8ef40da632528f98',
#  'link': 'https://kaliningrad.hh.ru/vacancy/41095804?query=Python',
#  'name': 'Бэк-энд разработчик (Python, SQL)',
#  'salary': ['от ',
#             '100\xa0000',
#             ' до ',
#             '160\xa0000',
#             ' ',
#             'руб.',
#             ' до вычета налогов'],
#  'salary_currency': 'руб.',
#  'salary_max': 160000,
#  'salary_min': 100000,
#  'site': 'hh'}
# 2021-03-29 21:14:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://russia.superjob.ru/vakansii/programmist-pyrus-35374424.html> (referer: https://russia.superjob.ru/vacancy/search/?keywords=Python)
# 2021-03-29 21:14:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://russia.superjob.ru/vakansii/programmist-python-36373575.html>
# {'_id': 'f83015375e9e18ac8cf18a6155c10cca6b178835',
#  'link': 'https://russia.superjob.ru/vakansii/programmist-python-36373575.html',
#  'name': 'Программист Python',
#  'salary': [],
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'superjobe'}
# 2021-03-29 21:14:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/43438280?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/42802585?query=Python>
# {'_id': '1ba1b67e132157767e5408753fa4de46d0ce06fd',
#  'link': 'https://kaliningrad.hh.ru/vacancy/42802585?query=Python',
#  'name': 'BackEnd Python-разработчик (Django)',
#  'salary': ['з/п не указана'],
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh'}
# 2021-03-29 21:14:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://russia.superjob.ru/vakansii/inzhener-po-nagruzochnomu-testirovaniyu-36496824.html>
# {'_id': 'e505a33dde78c6ecb978bc4036a1b9639c8ee214',
#  'link': 'https://russia.superjob.ru/vakansii/inzhener-po-nagruzochnomu-testirovaniyu-36496824.html',
#  'name': 'Инженер по нагрузочному тестированию',
#  'salary': [],
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'superjobe'}
# 2021-03-29 21:14:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/41469811?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://russia.superjob.ru/vakansii/prepodavatel-36173708.html> (referer: https://russia.superjob.ru/vacancy/search/?keywords=Python)
# 2021-03-29 21:14:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://russia.superjob.ru/vakansii/programmist-pyrus-35374424.html>
# {'_id': '80e293f792f2ed7057ed5216036890ed1628d616',
#  'link': 'https://russia.superjob.ru/vakansii/programmist-pyrus-35374424.html',
#  'name': 'Программист pyrus',
#  'salary': [],
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'superjobe'}
# 2021-03-29 21:14:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/43438280?query=Python>
# {'_id': 'd055502ee6e8299bdf1ea5b0ca3a256343749258',
#  'link': 'https://kaliningrad.hh.ru/vacancy/43438280?query=Python',
#  'name': 'Младший/middle Python разработчик',
#  'salary': ['з/п не указана'],
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh'}
# 2021-03-29 21:14:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/search/vacancy?L_is_autosearch=false&area=1&clusters=true&enable_snippets=true&text=Python&page=1> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/41469811?query=Python>
# {'_id': '5167c31708ecf0ebdba8c66a1bd25b15fbec4755',
#  'link': 'https://kaliningrad.hh.ru/vacancy/41469811?query=Python',
#  'name': 'Data Engineer',
#  'salary': ['от ', '250\xa0000', ' ', 'руб.', ' на руки'],
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': 250000,
#  'site': 'hh'}
# 2021-03-29 21:14:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/42453126?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/43369916?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://russia.superjob.ru/vakansii/prepodavatel-36173708.html>
# {'_id': 'f7cbcb6749779d393ba94ba2a43db970ba83c3d1',
#  'link': 'https://russia.superjob.ru/vakansii/prepodavatel-36173708.html',
#  'name': 'Преподаватель (в онлайн-школу программирования для детей 6-16 лет)',
#  'salary': [],
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'superjobe'}
# 2021-03-29 21:14:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/43118270?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/42453126?query=Python>
# {'_id': 'e80faf09c98a02652aaa0c6ced86fd71cd937e51',
#  'link': 'https://kaliningrad.hh.ru/vacancy/42453126?query=Python',
#  'name': 'Data Engineer',
#  'salary': ['от ', '200\xa0000', ' ', 'руб.', ' на руки'],
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': 200000,
#  'site': 'hh'}
# 2021-03-29 21:14:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/43369916?query=Python>
# {'_id': '6765a420dbd8e763bc896fce547d01e5ae1b1e36',
#  'link': 'https://kaliningrad.hh.ru/vacancy/43369916?query=Python',
#  'name': 'Junior Python Developer (Удалённая работа)',
#  'salary': ['з/п не указана'],
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh'}
# 2021-03-29 21:14:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://russia.superjob.ru/vakansii/python-developer-36176334.html> (referer: https://russia.superjob.ru/vacancy/search/?keywords=Python)
# 2021-03-29 21:14:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/42842536?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/43118270?query=Python>
# {'_id': 'e1584b996313e3ec87a1f537ce8161064a01af04',
#  'link': 'https://kaliningrad.hh.ru/vacancy/43118270?query=Python',
#  'name': 'Python backend разработчик (middle)',
#  'salary': ['от ', '120\xa0000', ' до ', '180\xa0000', ' ', 'руб.', ' на руки'],
#  'salary_currency': 'руб.',
#  'salary_max': 180000,
#  'salary_min': 120000,
#  'site': 'hh'}
# 2021-03-29 21:14:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/43422264?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://russia.superjob.ru/vakansii/starshij-sistemnyj-administrator-linux-36173787.html> (referer: https://russia.superjob.ru/vacancy/search/?keywords=Python)
# 2021-03-29 21:14:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://russia.superjob.ru/vakansii/python-developer-36176334.html>
# {'_id': 'e2fb2658d3c62bd6bfd050e6ddc9eaf59b7628e7',
#  'link': 'https://russia.superjob.ru/vakansii/python-developer-36176334.html',
#  'name': 'Python developer / Python разработчик / Программист Python',
#  'salary': [],
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'superjobe'}
# 2021-03-29 21:14:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/42251823?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/42842536?query=Python>
# {'_id': '06cc589a5cb7b68ca733ec043e9f379474a784c9',
#  'link': 'https://kaliningrad.hh.ru/vacancy/42842536?query=Python',
#  'name': 'Python разработчик',
#  'salary': ['от ', '60\xa0000', ' ', 'руб.', ' на руки'],
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': 60000,
#  'site': 'hh'}
# 2021-03-29 21:14:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/42770299?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/42676588?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/43422264?query=Python>
# {'_id': '26890911496a5d675640e6afc297d8c3e3a984c5',
#  'link': 'https://kaliningrad.hh.ru/vacancy/43422264?query=Python',
#  'name': 'Senior/Middle ML Engineer (Data Scientist)',
#  'salary': ['от ', '200\xa0000', ' ', 'руб.', ' на руки'],
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': 200000,
#  'site': 'hh'}
# 2021-03-29 21:14:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://russia.superjob.ru/vakansii/starshij-sistemnyj-administrator-linux-36173787.html>
# {'_id': '74f970b93743568768c3f4f570129f3e7a945406',
#  'link': 'https://russia.superjob.ru/vakansii/starshij-sistemnyj-administrator-linux-36173787.html',
#  'name': 'Старший системный администратор Linux',
#  'salary': [],
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'superjobe'}
# 2021-03-29 21:14:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/42251823?query=Python>
# {'_id': '5f156bb045e362694f366b8688fdcf628cd37460',
#  'link': 'https://kaliningrad.hh.ru/vacancy/42251823?query=Python',
#  'name': 'Программист-математик/Алгоритмист (США)',
#  'salary': ['до ', '7\xa0000', ' ', 'USD', ' до вычета налогов'],
#  'salary_currency': 'USD',
#  'salary_max': 7000,
#  'salary_min': None,
#  'site': 'hh'}
# 2021-03-29 21:14:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/43308988?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://russia.superjob.ru/vacancy/search/?keywords=Python&page=2> (referer: https://russia.superjob.ru/vacancy/search/?keywords=Python)
# 2021-03-29 21:14:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/42770299?query=Python>
# {'_id': '79eda61311dc0cbc6e70af63158d3228f062c5d6',
#  'link': 'https://kaliningrad.hh.ru/vacancy/42770299?query=Python',
#  'name': 'Backend Python Developer (USD Salary, Remote)',
#  'salary': ['от ', '250\xa0000', ' ', 'руб.', ' на руки'],
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': 250000,
#  'site': 'hh'}
# 2021-03-29 21:14:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/42676588?query=Python>
# {'_id': 'd2111ed0bf633354276bb1b76bdca7c2d7b09027',
#  'link': 'https://kaliningrad.hh.ru/vacancy/42676588?query=Python',
#  'name': 'Python Программист разработчик',
#  'salary': ['з/п не указана'],
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh'}
# 2021-03-29 21:14:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://russia.superjob.ru/vakansii/analitik-bazy-dannyh-36302264.html> (referer: https://russia.superjob.ru/vacancy/search/?keywords=Python)
# 2021-03-29 21:14:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/43155622?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/43308988?query=Python>
# {'_id': '3cc5f3ebd38569a1bd8859374827e5628ac08bbd',
#  'link': 'https://kaliningrad.hh.ru/vacancy/43308988?query=Python',
#  'name': 'Python разработчик (Django)',
#  'salary': ['от ', '100\xa0000', ' ', 'руб.', ' на руки'],
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': 100000,
#  'site': 'hh'}
# 2021-03-29 21:14:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://russia.superjob.ru/vakansii/senior-python-razrabotchik-36183343.html> (referer: https://russia.superjob.ru/vacancy/search/?keywords=Python)
# 2021-03-29 21:14:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://russia.superjob.ru/vakansii/backend-razrabotchik-python-35151272.html> (referer: https://russia.superjob.ru/vacancy/search/?keywords=Python)
# 2021-03-29 21:14:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://russia.superjob.ru/vakansii/programmist-python-36270453.html> (referer: https://russia.superjob.ru/vacancy/search/?keywords=Python)
# 2021-03-29 21:14:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/42799332?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://russia.superjob.ru/vakansii/senior-python-developer-36391472.html> (referer: https://russia.superjob.ru/vacancy/search/?keywords=Python)
# 2021-03-29 21:14:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://russia.superjob.ru/vakansii/analitik-bazy-dannyh-36302264.html>
# {'_id': '7cdbe2d6a5dc97add1b30743fb3e674ca6709d82',
#  'link': 'https://russia.superjob.ru/vakansii/analitik-bazy-dannyh-36302264.html',
#  'name': 'Аналитик базы данных / Разработчик Python',
#  'salary': [],
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'superjobe'}
# 2021-03-29 21:14:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/43155622?query=Python>
# {'_id': 'e051e8873d61d05ebfb1486635eb66155461e55b',
#  'link': 'https://kaliningrad.hh.ru/vacancy/43155622?query=Python',
#  'name': 'Data Engineer (Clickhouse), удаленно',
#  'salary': ['от ', '150\xa0000', ' до ', '250\xa0000', ' ', 'руб.', ' на руки'],
#  'salary_currency': 'руб.',
#  'salary_max': 250000,
#  'salary_min': 150000,
#  'site': 'hh'}
# 2021-03-29 21:14:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/43390032?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/42144364?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://russia.superjob.ru/vakansii/senior-python-razrabotchik-36183343.html>
# {'_id': '8d6c5189ba203e3bd9e9d7c643d70609f09d9529',
#  'link': 'https://russia.superjob.ru/vakansii/senior-python-razrabotchik-36183343.html',
#  'name': 'Senior Python разработчик',
#  'salary': [],
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'superjobe'}
# 2021-03-29 21:14:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://russia.superjob.ru/vakansii/backend-razrabotchik-python-35151272.html>
# {'_id': 'e3dff8c5bda096781b1a88ec965024629c3d72ce',
#  'link': 'https://russia.superjob.ru/vakansii/backend-razrabotchik-python-35151272.html',
#  'name': 'Backend-разработчик Python',
#  'salary': [],
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'superjobe'}
# 2021-03-29 21:14:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/43354290?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://russia.superjob.ru/vakansii/programmist-python-36270453.html>
# {'_id': '556c6782f180404a0e65fe9a4bb7b143b79b367f',
#  'link': 'https://russia.superjob.ru/vakansii/programmist-python-36270453.html',
#  'name': 'Программист Python',
#  'salary': [],
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'superjobe'}
# 2021-03-29 21:14:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/42799332?query=Python>
# {'_id': '529d93b6087cf83c01b1cd147f4e78532e72f404',
#  'link': 'https://kaliningrad.hh.ru/vacancy/42799332?query=Python',
#  'name': 'Python (Django) разработчик',
#  'salary': ['от ', '70\xa0000', ' ', 'руб.', ' на руки'],
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': 70000,
#  'site': 'hh'}
# 2021-03-29 21:14:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/43423259?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://russia.superjob.ru/vakansii/senior-python-developer-36391472.html>
# {'_id': '5a95ecb715c982ba05d10684ed98380e4e3b3244',
#  'link': 'https://russia.superjob.ru/vakansii/senior-python-developer-36391472.html',
#  'name': 'Senior Python Developer',
#  'salary': [],
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'superjobe'}
# 2021-03-29 21:14:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/43390032?query=Python>
# {'_id': 'ce2724667c7c24efc3007261ca0a36c9b0a59370',
#  'link': 'https://kaliningrad.hh.ru/vacancy/43390032?query=Python',
#  'name': 'Data Scientist (Junior +)',
#  'salary': ['з/п не указана'],
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh'}
# 2021-03-29 21:14:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/42144364?query=Python>
# {'_id': '554a223aab0f86c9b25f2eced726d6660ec5e972',
#  'link': 'https://kaliningrad.hh.ru/vacancy/42144364?query=Python',
#  'name': 'Разработчик моделей оптимизации (Python)',
#  'salary': ['от ', '200\xa0000', ' ', 'руб.', ' на руки'],
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': 200000,
#  'site': 'hh'}
# 2021-03-29 21:14:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://russia.superjob.ru/vakansii/programmist-python-36410905.html> (referer: https://russia.superjob.ru/vacancy/search/?keywords=Python)
# 2021-03-29 21:14:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/42783010?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/43354290?query=Python>
# {'_id': '98cc95e9e1cfc22e75da893a66284099127bf3aa',
#  'link': 'https://kaliningrad.hh.ru/vacancy/43354290?query=Python',
#  'name': 'Ведущий аналитик данных / Data Scientist',
#  'salary': ['до ', '300\xa0000', ' ', 'руб.', ' до вычета налогов'],
#  'salary_currency': 'руб.',
#  'salary_max': 300000,
#  'salary_min': None,
#  'site': 'hh'}
# 2021-03-29 21:14:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/42011548?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/43423259?query=Python>
# {'_id': 'e8fba4cbcd7c59d3e2b96fab29f4936509ae35fe',
#  'link': 'https://kaliningrad.hh.ru/vacancy/43423259?query=Python',
#  'name': 'Senior Python Developer',
#  'salary': ['от ', '200\xa0000', ' ', 'руб.', ' на руки'],
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': 200000,
#  'site': 'hh'}
# 2021-03-29 21:14:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/43088142?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/42555938?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://russia.superjob.ru/vakansii/programmist-python-36410905.html>
# {'_id': 'a65b920a5030826affefa82feefa824aff266a32',
#  'link': 'https://russia.superjob.ru/vakansii/programmist-python-36410905.html',
#  'name': 'Программист Python',
#  'salary': [],
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'superjobe'}
# 2021-03-29 21:14:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/42783010?query=Python>
# {'_id': 'cd111597762879751813fd12788291ca9b436af3',
#  'link': 'https://kaliningrad.hh.ru/vacancy/42783010?query=Python',
#  'name': 'Python / C++ разработчик',
#  'salary': ['от ', '150\xa0000', ' до ', '200\xa0000', ' ', 'руб.', ' на руки'],
#  'salary_currency': 'руб.',
#  'salary_max': 200000,
#  'salary_min': 150000,
#  'site': 'hh'}
# 2021-03-29 21:14:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/42814545?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/42011548?query=Python>
# {'_id': '7be987005124cedcca95ee407b0f1dcf6f804cb3',
#  'link': 'https://kaliningrad.hh.ru/vacancy/42011548?query=Python',
#  'name': 'Data Scientist',
#  'salary': ['от ',
#             '150\xa0000',
#             ' до ',
#             '280\xa0000',
#             ' ',
#             'руб.',
#             ' до вычета налогов'],
#  'salary_currency': 'руб.',
#  'salary_max': 280000,
#  'salary_min': 150000,
#  'site': 'hh'}
# 2021-03-29 21:14:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/43088142?query=Python>
# {'_id': '21909f16992327cce2ca3813f5692ce8f4da7c7f',
#  'link': 'https://kaliningrad.hh.ru/vacancy/43088142?query=Python',
#  'name': 'Data Engineer',
#  'salary': ['от ',
#             '60\xa0000',
#             ' до ',
#             '110\xa0000',
#             ' ',
#             'руб.',
#             ' до вычета налогов'],
#  'salary_currency': 'руб.',
#  'salary_max': 110000,
#  'salary_min': 60000,
#  'site': 'hh'}
# 2021-03-29 21:14:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/42555938?query=Python>
# {'_id': 'bab0ec15716670af4ba0bf76855acb6c62576614',
#  'link': 'https://kaliningrad.hh.ru/vacancy/42555938?query=Python',
#  'name': 'Python Backend разработчик',
#  'salary': ['от ', '150\xa0000', ' до ', '250\xa0000', ' ', 'руб.', ' на руки'],
#  'salary_currency': 'руб.',
#  'salary_max': 250000,
#  'salary_min': 150000,
#  'site': 'hh'}
# 2021-03-29 21:14:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/43371507?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/42814545?query=Python>
# {'_id': '3402516df17b2dc48f1fe23b560ca29e3f14639c',
#  'link': 'https://kaliningrad.hh.ru/vacancy/42814545?query=Python',
#  'name': 'Аналитик / Data Analyst (Product Analyst)',
#  'salary': ['от ', '100\xa0000', ' ', 'руб.', ' на руки'],
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': 100000,
#  'site': 'hh'}
# 2021-03-29 21:14:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/41467833?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://russia.superjob.ru/vakansii/django-36422965.html> (referer: https://russia.superjob.ru/vacancy/search/?keywords=Python)
# 2021-03-29 21:14:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/40551245?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?L_is_autosearch=false&area=1&clusters=true&enable_snippets=true&text=Python&page=1)
# 2021-03-29 21:14:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/43371507?query=Python>
# {'_id': '57b3c4d53fd188fbab18339a52b98814e2d88f97',
#  'link': 'https://kaliningrad.hh.ru/vacancy/43371507?query=Python',
#  'name': 'Golang/Python разработчик',
#  'salary': ['от ', '150\xa0000', ' ', 'руб.', ' до вычета налогов'],
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': 150000,
#  'site': 'hh'}
# 2021-03-29 21:14:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/43422230?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python)
# 2021-03-29 21:14:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/42743995?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?L_is_autosearch=false&area=1&clusters=true&enable_snippets=true&text=Python&page=1)
# 2021-03-29 21:14:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/41467833?query=Python>
# {'_id': 'c6731f47357af5d445ac95314ed0be7cd554785b',
#  'link': 'https://kaliningrad.hh.ru/vacancy/41467833?query=Python',
#  'name': 'Senior QA Automation Engineer (Python)',
#  'salary': ['от ', '300\xa0000', ' ', 'руб.', ' на руки'],
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': 300000,
#  'site': 'hh'}
# 2021-03-29 21:14:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://russia.superjob.ru/vakansii/django-36422965.html>
# {'_id': '4309a9361477b215ee3d3d70f5d1da7ac492c09d',
#  'link': 'https://russia.superjob.ru/vakansii/django-36422965.html',
#  'name': 'Django/Python Developer',
#  'salary': [],
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'superjobe'}
# 2021-03-29 21:14:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/40551245?query=Python>
# {'_id': 'fb5dc616ee8fb36077fd055386e709e8d84b1380',
#  'link': 'https://kaliningrad.hh.ru/vacancy/40551245?query=Python',
#  'name': 'Разработчик (Python)',
#  'salary': ['от ',
#             '100\xa0000',
#             ' до ',
#             '160\xa0000',
#             ' ',
#             'руб.',
#             ' до вычета налогов'],
#  'salary_currency': 'руб.',
#  'salary_max': 160000,
#  'salary_min': 100000,
#  'site': 'hh'}
# 2021-03-29 21:14:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/35871016?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?L_is_autosearch=false&area=1&clusters=true&enable_snippets=true&text=Python&page=1)
# ...
#  'site': 'hh'}
# 2021-03-29 21:16:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/43435041?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?L_is_autosearch=false&area=1&clusters=true&enable_snippets=true&text=Python&page=3)
# 2021-03-29 21:16:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/42829377?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?L_is_autosearch=false&area=1&clusters=true&enable_snippets=true&text=Python&page=3)
# 2021-03-29 21:16:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/43435041?query=Python>
# {'_id': '8d2c6c2c50b851ca639cc899760069da8b4340d2',
#  'link': 'https://kaliningrad.hh.ru/vacancy/43435041?query=Python',
#  'name': 'Программист Python (ML)',
#  'salary': ['з/п не указана'],
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh'}
# 2021-03-29 21:16:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/43358370?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?L_is_autosearch=false&area=1&clusters=true&enable_snippets=true&text=Python&page=3)
# 2021-03-29 21:16:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/42829377?query=Python>
# {'_id': '4a99080fbb9a481ca80664ab2b28584cadc32f67',
#  'link': 'https://kaliningrad.hh.ru/vacancy/42829377?query=Python',
#  'name': 'Python разработчик',
#  'salary': ['з/п не указана'],
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh'}
# 2021-03-29 21:16:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/42740587?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?L_is_autosearch=false&area=1&clusters=true&enable_snippets=true&text=Python&page=3)
# 2021-03-29 21:16:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/43433951?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?L_is_autosearch=false&area=1&clusters=true&enable_snippets=true&text=Python&page=3)
# 2021-03-29 21:16:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/43416469?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?L_is_autosearch=false&area=1&clusters=true&enable_snippets=true&text=Python&page=3)
# 2021-03-29 21:16:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/43358370?query=Python>
# {'_id': '4d4bdc0a551ee9e1ae2195bdf6ce56b6989b2ed2',
#  'link': 'https://kaliningrad.hh.ru/vacancy/43358370?query=Python',
#  'name': 'Python разработчик',
#  'salary': ['от ', '120\xa0000', ' до ', '140\xa0000', ' ', 'руб.', ' на руки'],
#  'salary_currency': 'руб.',
#  'salary_max': 140000,
#  'salary_min': 120000,
#  'site': 'hh'}
# 2021-03-29 21:16:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/42740587?query=Python>
# {'_id': '64b35e02d97428d3f27cb5f79bd2f1d79aacfc32',
#  'link': 'https://kaliningrad.hh.ru/vacancy/42740587?query=Python',
#  'name': 'Python-разработчик (группа биллинга myTarget)',
#  'salary': ['з/п не указана'],
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh'}
# 2021-03-29 21:16:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/43433951?query=Python>
# {'_id': 'b99ae6e3e473fe71b7e6d98b57263b2f34ba8b9e',
#  'link': 'https://kaliningrad.hh.ru/vacancy/43433951?query=Python',
#  'name': 'Python-разработчик (разработчик в тестировании)',
#  'salary': ['з/п не указана'],
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh'}
# 2021-03-29 21:16:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/43416469?query=Python>
# {'_id': '2a137143f61319f3b7ebb8b2e411f9fbce2af5a5',
#  'link': 'https://kaliningrad.hh.ru/vacancy/43416469?query=Python',
#  'name': 'Python-разработчик (Платформа рекомендаций)',
#  'salary': ['з/п не указана'],
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh'}
# 2021-03-29 21:16:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/43371816?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?L_is_autosearch=false&area=1&clusters=true&enable_snippets=true&text=Python&page=2)
# 2021-03-29 21:16:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/42547797?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?L_is_autosearch=false&area=1&clusters=true&enable_snippets=true&text=Python&page=2)
# 2021-03-29 21:16:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/43371816?query=Python>
# {'_id': '59648924457c504e8c6d1e113ae8886786897eff',
#  'link': 'https://kaliningrad.hh.ru/vacancy/43371816?query=Python',
#  'name': 'Аналитик (Tableau, Python)',
#  'salary': ['з/п не указана'],
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh'}
# 2021-03-29 21:16:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/43370540?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?L_is_autosearch=false&area=1&clusters=true&enable_snippets=true&text=Python&page=2)
# 2021-03-29 21:16:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/42547797?query=Python>
# {'_id': 'b4bcdb663f8fd79e34fb4e2a51c4822af67c16ce',
#  'link': 'https://kaliningrad.hh.ru/vacancy/42547797?query=Python',
#  'name': 'Старший разработчик (Python)',
#  'salary': ['от ',
#             '160\xa0000',
#             ' до ',
#             '190\xa0000',
#             ' ',
#             'руб.',
#             ' до вычета налогов'],
#  'salary_currency': 'руб.',
#  'salary_max': 190000,
#  'salary_min': 160000,
#  'site': 'hh'}
# 2021-03-29 21:16:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/42028953?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?L_is_autosearch=false&area=1&clusters=true&enable_snippets=true&text=Python&page=2)
# 2021-03-29 21:16:45 [scrapy.extensions.logstats] INFO: Crawled 2022 pages (at 1030 pages/min), scraped 1980 items (at 1018 items/min)
# 2021-03-29 21:16:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/42932721?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?L_is_autosearch=false&area=1&clusters=true&enable_snippets=true&text=Python&page=2)
# 2021-03-29 21:16:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/43370540?query=Python>
# {'_id': 'a9fb80f2add20a96a9d811837766b461c2419155',
#  'link': 'https://kaliningrad.hh.ru/vacancy/43370540?query=Python',
#  'name': 'Разработчик Python',
#  'salary': ['з/п не указана'],
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh'}
# 2021-03-29 21:16:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/42028953?query=Python>
# {'_id': '26b420d9585647580e3ac369382cd9c8b2d88879',
#  'link': 'https://kaliningrad.hh.ru/vacancy/42028953?query=Python',
#  'name': 'Data Engineer',
#  'salary': ['от ', '150\xa0000', ' до ', '200\xa0000', ' ', 'руб.', ' на руки'],
#  'salary_currency': 'руб.',
#  'salary_max': 200000,
#  'salary_min': 150000,
#  'site': 'hh'}
# 2021-03-29 21:16:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/43398362?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?L_is_autosearch=false&area=1&clusters=true&enable_snippets=true&text=Python&page=3)
# 2021-03-29 21:16:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/42932721?query=Python>
# {'_id': '72bfeda8d8d2fdfdadd02b20a0ad8c94dc08b085',
#  'link': 'https://kaliningrad.hh.ru/vacancy/42932721?query=Python',
#  'name': 'Senior C++ developer',
#  'salary': ['от ', '200\xa0000', ' до ', '300\xa0000', ' ', 'руб.', ' на руки'],
#  'salary_currency': 'руб.',
#  'salary_max': 300000,
#  'salary_min': 200000,
#  'site': 'hh'}
# 2021-03-29 21:16:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/43050718?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?L_is_autosearch=false&area=1&clusters=true&enable_snippets=true&text=Python&page=2)
# 2021-03-29 21:16:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/43398362?query=Python>
# {'_id': 'fa4cac73984cffd064584e56a6ec92eff102765e',
#  'link': 'https://kaliningrad.hh.ru/vacancy/43398362?query=Python',
#  'name': 'QA automation (Python)',
#  'salary': ['з/п не указана'],
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh'}
# 2021-03-29 21:16:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/42695058?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?L_is_autosearch=false&area=1&clusters=true&enable_snippets=true&text=Python&page=3)
# 2021-03-29 21:16:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/42779913?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?L_is_autosearch=false&area=1&clusters=true&enable_snippets=true&text=Python&page=2)
# 2021-03-29 21:16:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/43050718?query=Python>
# {'_id': 'efc1bc8cc9c8b6bc60fed09df1f2f1526318b932',
#  'link': 'https://kaliningrad.hh.ru/vacancy/43050718?query=Python',
#  'name': 'Backend разработчик (Python)',
#  'salary': ['з/п не указана'],
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh'}
# 2021-03-29 21:16:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/43379499?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?L_is_autosearch=false&area=1&clusters=true&enable_snippets=true&text=Python&page=3)
# 2021-03-29 21:16:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/43270626?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?L_is_autosearch=false&area=1&clusters=true&enable_snippets=true&text=Python&page=2)
# 2021-03-29 21:16:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/43180331?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?L_is_autosearch=false&area=1&clusters=true&enable_snippets=true&text=Python&page=2)
# 2021-03-29 21:16:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/42695058?query=Python>
# {'_id': 'a2a2886cd57724b91b84a29825f0d89258187db2',
#  'link': 'https://kaliningrad.hh.ru/vacancy/42695058?query=Python',
#  'name': 'Web-разработчик (Python)',
#  'salary': ['з/п не указана'],
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh'}
# 2021-03-29 21:16:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/42779913?query=Python>
# {'_id': 'dbb6170d1c715cd2aed9155a5f0e4ff1e7d565d0',
#  'link': 'https://kaliningrad.hh.ru/vacancy/42779913?query=Python',
#  'name': 'Junior Python developer',
#  'salary': ['з/п не указана'],
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh'}
# 2021-03-29 21:16:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/43379499?query=Python>
# {'_id': 'e1fa695529255cac9a37c21673a3194ee836498b',
#  'link': 'https://kaliningrad.hh.ru/vacancy/43379499?query=Python',
#  'name': 'Разработчик Python',
#  'salary': ['з/п не указана'],
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh'}
# 2021-03-29 21:16:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/43394792?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?L_is_autosearch=false&area=1&clusters=true&enable_snippets=true&text=Python&page=2)
# 2021-03-29 21:16:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/43270626?query=Python>
# {'_id': '8f9d1a43c066e36f76a251bf5e18e268bd6363f8',
#  'link': 'https://kaliningrad.hh.ru/vacancy/43270626?query=Python',
#  'name': 'Python Scrapy Developer',
#  'salary': [],
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh'}
# 2021-03-29 21:16:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/42843371?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?L_is_autosearch=false&area=1&clusters=true&enable_snippets=true&text=Python&page=2)
# 2021-03-29 21:16:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/43180331?query=Python>
# {'_id': '419c7da43a8fb0ebbcd158afd50aa4a96b23c7c2',
#  'link': 'https://kaliningrad.hh.ru/vacancy/43180331?query=Python',
#  'name': 'Python Middle (Back-End)',
#  'salary': ['от ', '120\xa0000', ' ', 'руб.', ' до вычета налогов'],
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': 120000,
#  'site': 'hh'}
# 2021-03-29 21:16:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/43394792?query=Python>
# {'_id': '930946e43fa8c42af11276763cf6689e4bbb59d6',
#  'link': 'https://kaliningrad.hh.ru/vacancy/43394792?query=Python',
#  'name': 'Senior Python Developer',
#  'salary': ['з/п не указана'],
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh'}
# 2021-03-29 21:16:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/42843371?query=Python>
# {'_id': 'bb29e2fb8fa523a142daa4ef8115b3ed0daa7065',
#  'link': 'https://kaliningrad.hh.ru/vacancy/42843371?query=Python',
#  'name': 'Python Developer',
#  'salary': ['от ', '2\xa0000', ' ', 'EUR', ' до вычета налогов'],
#  'salary_currency': 'EUR',
#  'salary_max': None,
#  'salary_min': 2000,
#  'site': 'hh'}
# 2021-03-29 21:16:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/43068966?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?L_is_autosearch=false&area=1&clusters=true&enable_snippets=true&text=Python&page=1)
# 2021-03-29 21:16:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/43068966?query=Python>
# {'_id': '3548dc4ccb60b4062517ddb1085ddcea0a370c41',
#  'link': 'https://kaliningrad.hh.ru/vacancy/43068966?query=Python',
#  'name': 'Разработчик Python',
#  'salary': ['з/п не указана'],
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh'}
# 2021-03-29 21:16:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://kaliningrad.hh.ru/vacancy/39388485?query=Python> (referer: https://kaliningrad.hh.ru/search/vacancy?L_is_autosearch=false&area=1&clusters=true&enable_snippets=true&text=Python&page=1)
# 2021-03-29 21:16:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://kaliningrad.hh.ru/vacancy/39388485?query=Python>
# {'_id': '245e1a6c1f806471b62dfe92b81e76db4fa0e5f0',
#  'link': 'https://kaliningrad.hh.ru/vacancy/39388485?query=Python',
#  'name': 'Senior Python Backend Developer (Machine Learning)',
#  'salary': ['от ', '250\xa0000', ' ', 'руб.', ' на руки'],
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': 250000,
#  'site': 'hh'}
# 2021-03-29 21:16:46 [scrapy.core.engine] INFO: Closing spider (finished)
# 2021-03-29 21:16:46 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 1481795,
#  'downloader/request_count': 2034,
#  'downloader/request_method_count/GET': 2034,
#  'downloader/response_bytes': 356363923,
#  'downloader/response_count': 2034,
#  'downloader/response_status_count/200': 2034,
#  'dupefilter/filtered': 6,
#  'elapsed_time_seconds': 120.972674,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2021, 3, 29, 18, 16, 46, 589013),
#  'item_scraped_count': 1994,
#  'log_count/DEBUG': 4267,
#  'log_count/ERROR': 2,
#  'log_count/INFO': 24,
#  'request_depth_max': 40,
#  'response_received_count': 2034,
#  'scheduler/dequeued': 2034,
#  'scheduler/dequeued/memory': 2034,
#  'scheduler/enqueued': 2034,
#  'scheduler/enqueued/memory': 2034,
#  'spider_exceptions/ValueError': 1,
#  'start_time': datetime.datetime(2021, 3, 29, 18, 14, 45, 616339)}
# 2021-03-29 21:16:46 [scrapy.core.engine] INFO: Spider closed (finished)
