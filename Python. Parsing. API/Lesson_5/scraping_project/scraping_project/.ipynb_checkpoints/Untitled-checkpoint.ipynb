# %%
from scrapy.crawler import CrawlerProcess
from scrapy.settings import Settings

from jobparser.spiders.hhru import HhruSpider
from jobparser.spiders.superjoberu import SuperjobRuSpider
from jobparser import settings

# %%
crawler_settings = Settings()
crawler_settings.setmodule(settings)
process = CrawlerProcess(settings=crawler_settings)

process.crawl(HhruSpider,vacancy = 'Python')
#process.crawl(SuperjobRuSpider,vacancy = 'Python')
process.start()
# Out:
# Unhandled error in Deferred:
# 2021-03-29 20:50:21 [twisted] CRITICAL: Unhandled error in Deferred:
# 2021-03-29 20:50:21 [twisted] CRITICAL: Unhandled error in Deferred:
# 2021-03-29 20:50:21 [twisted] CRITICAL: Unhandled error in Deferred:
#
# Traceback (most recent call last):
#   File "D:\Programme\Anaconda\lib\site-packages\scrapy\crawler.py", line 192, in crawl
#     return self._crawl(crawler, *args, **kwargs)
#   File "D:\Programme\Anaconda\lib\site-packages\scrapy\crawler.py", line 196, in _crawl
#     d = crawler.crawl(*args, **kwargs)
#   File "D:\Programme\Anaconda\lib\site-packages\twisted\internet\defer.py", line 1656, in unwindGenerator
#     return _cancellableInlineCallbacks(gen)
#   File "D:\Programme\Anaconda\lib\site-packages\twisted\internet\defer.py", line 1571, in _cancellableInlineCallbacks
#     _inlineCallbacks(None, g, status)
# --- <exception caught here> ---
#   File "D:\Programme\Anaconda\lib\site-packages\twisted\internet\defer.py", line 1445, in _inlineCallbacks
#     result = current_context.run(g.send, result)
#   File "D:\Programme\Anaconda\lib\site-packages\scrapy\crawler.py", line 86, in crawl
#     self.spider = self._create_spider(*args, **kwargs)
#   File "D:\Programme\Anaconda\lib\site-packages\scrapy\crawler.py", line 98, in _create_spider
#     return self.spidercls.from_crawler(self, *args, **kwargs)
#   File "D:\Programme\Anaconda\lib\site-packages\scrapy\spiders\__init__.py", line 50, in from_crawler
#     spider = cls(*args, **kwargs)
# builtins.TypeError: __init__() got an unexpected keyword argument 'vacansy'
#
# 2021-03-29 20:50:21 [twisted] CRITICAL:
# Traceback (most recent call last):
#   File "D:\Programme\Anaconda\lib\site-packages\twisted\internet\defer.py", line 1445, in _inlineCallbacks
#     result = current_context.run(g.send, result)
#   File "D:\Programme\Anaconda\lib\site-packages\scrapy\crawler.py", line 86, in crawl
#     self.spider = self._create_spider(*args, **kwargs)
#   File "D:\Programme\Anaconda\lib\site-packages\scrapy\crawler.py", line 98, in _create_spider
#     return self.spidercls.from_crawler(self, *args, **kwargs)
#   File "D:\Programme\Anaconda\lib\site-packages\scrapy\spiders\__init__.py", line 50, in from_crawler
#     spider = cls(*args, **kwargs)
# TypeError: __init__() got an unexpected keyword argument 'vacansy'
# 2021-03-29 20:50:21 [twisted] CRITICAL:
# Traceback (most recent call last):
#   File "D:\Programme\Anaconda\lib\site-packages\twisted\internet\defer.py", line 1445, in _inlineCallbacks
#     result = current_context.run(g.send, result)
#   File "D:\Programme\Anaconda\lib\site-packages\scrapy\crawler.py", line 86, in crawl
#     self.spider = self._create_spider(*args, **kwargs)
#   File "D:\Programme\Anaconda\lib\site-packages\scrapy\crawler.py", line 98, in _create_spider
#     return self.spidercls.from_crawler(self, *args, **kwargs)
#   File "D:\Programme\Anaconda\lib\site-packages\scrapy\spiders\__init__.py", line 50, in from_crawler
#     spider = cls(*args, **kwargs)
# TypeError: __init__() got an unexpected keyword argument 'vacansy'
# 2021-03-29 20:50:21 [twisted] CRITICAL:
# Traceback (most recent call last):
#   File "D:\Programme\Anaconda\lib\site-packages\twisted\internet\defer.py", line 1445, in _inlineCallbacks
#     result = current_context.run(g.send, result)
#   File "D:\Programme\Anaconda\lib\site-packages\scrapy\crawler.py", line 86, in crawl
#     self.spider = self._create_spider(*args, **kwargs)
#   File "D:\Programme\Anaconda\lib\site-packages\scrapy\crawler.py", line 98, in _create_spider
#     return self.spidercls.from_crawler(self, *args, **kwargs)
#   File "D:\Programme\Anaconda\lib\site-packages\scrapy\spiders\__init__.py", line 50, in from_crawler
#     spider = cls(*args, **kwargs)
# TypeError: __init__() got an unexpected keyword argument 'vacansy'
# 2021-03-29 20:50:21 [scrapy.utils.log] INFO: Scrapy 2.4.1 started (bot: jobparser)
# 2021-03-29 20:50:21 [scrapy.utils.log] INFO: Versions: lxml 4.2.5.0, libxml2 2.9.8, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 21.2.0, Python 3.7.1 (default, Dec 10 2018, 22:54:23) [MSC v.1915 64 bit (AMD64)], pyOpenSSL 18.0.0 (OpenSSL 1.1.1c  28 May 2019), cryptography 2.4.2, Platform Windows-10-10.0.19041-SP0
# 2021-03-29 20:50:21 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2021-03-29 20:50:21 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'jobparser',
#  'CONCURRENT_REQUESTS': 32,
#  'NEWSPIDER_MODULE': 'jobparser.spiders',
#  'SPIDER_MODULES': ['jobparser.spiders'],
#  'USER_AGENT': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, '
#                'like Gecko) Chrome/88.0.4324.96 Safari/537.36'}
# 2021-03-29 20:50:21 [scrapy.extensions.telnet] INFO: Telnet Password: 0bdc6977ea90ad34
# 2021-03-29 20:50:21 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2021-03-29 20:50:21 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2021-03-29 20:50:21 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
